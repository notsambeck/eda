# %%
import pandas as pd
import sqlalchemy as sql
import matplotlib.pyplot as plt
# %matplotlib inline

from tqdm import tqdm

# %% [markdown]
# # Build a recommender using PCA tools
#
# ### Load data

# %%
pca_dimension = 16   # number of coordinates generated previously

# %%
engine = sql.create_engine('sqlite:///instacart.db')
db = {}

# %%
for table in ['order_products', 'departments', 'aisles']:
    db[table] = pd.read_sql_table(table, engine, index_col=0,)

# %%
orders = db['order_products'].groupby('order_id')['product_id'].unique()   # orders = list of products in each order

# %%
pca_frame = pd.read_csv('product_pca_coords.csv', index_col=0)
pca_frame.values[:, :pca_dimension] = pca_frame.values[:, :pca_dimension].astype('float')

# %% [markdown]
# ### Visualize loaded data to make sure it's intact

# %%
keywords = [
    'organic',
    'fresh',
    'chocolate',
    'gluten',
    ]

colors = [
    'purple',
    'green',
    'gray',
    'blue',
    ]

groups = list(zip(keywords, colors))

num=40000
rows = 4

fig, ax = plt.subplots(nrows=rows)
fig.set_size_inches(11, 20)

for i in range(rows):
    for series, color in groups:
        mask = pca_frame.product_name.str.lower().str.contains(series)
        label = series
        ax[i].scatter(x=pca_frame[mask].values[:, i].reshape(-1), 
                      y=pca_frame[mask].values[:, i+1].reshape(-1),
                      c=color,
                      alpha=.6,
                      s=2,
                      label=label,
                      )
    
ax[0].legend()

# %% [markdown]
# ### Make some distance functions

# %%
def closest_product(product_id, output='scores'):
    try:
        print('best match for:', pca_frame.product_name.loc[product_id])
        my_coords = pca_frame.loc[product_id].values[:pca_dimension].astype('float32')
        actual_index = pca_frame.index.get_loc(product_id)
        # print(actual_index)
    except KeyError:
        print('invalid item')
        return None
    
    diff = pca_frame.values[:, :pca_dimension].astype('float32') - my_coords
    # print(diff.shape, diff.dtype)
    scores = pd.np.linalg.norm(diff, axis=1)
    scores[actual_index] = pd.np.Inf
    # print(scores[:5])

    best = pd.np.argmin(scores)
    if output == 'scores':
        print(pca_frame.product_name.iloc[best])
        return scores
    else:
        return best, pca_frame.product_name.iloc[best], pca_frame.index[best], pd.np.min(scores)

# %%
def distance(product_id, target_id):
    try:
        print('distance from:', pca_frame.product_name.loc[product_id], ' to ', pca_frame.product_name.loc[target_id])
        my_coords = pca_frame.loc[product_id].values[:pca_dimension].astype('float32')
        target = pca_frame.loc[target_id].values[:pca_dimension].astype('float32')
        # print(actual_index)
    except KeyError:
        print('invalid item')
        return None
    
    return pd.np.linalg.norm(my_coords - target)

# %%
def multi_closest_product(basket):
    point_cloud = pd.np.empty((len(basket), pca_dimension), dtype='float32')
    indices = []
    row = 0
    for product_id in basket:
        try:
            print('best match for:', pca_frame.product_name.loc[product_id])
            coords = pca_frame.loc[product_id].values[:pca_dimension].astype('float32')
            point_cloud[row] = coords
            indices.append(pca_frame.index.get_loc(product_id))
            # print(actual_index)
            row += 1
        except KeyError:
            print('invalid item')
            return None
    
    my_coords = pd.np.mean(point_cloud, axis=0)
    print(my_coords.shape)

    diff = pca_frame.values[:, :pca_dimension].astype('float32') - my_coords
    # print(diff.shape, diff.dtype)
    scores = pd.np.linalg.norm(diff, axis=1)
    for i in indices:
        scores[i] = pd.np.Inf
    # print(scores[:5])

    best = pd.np.argmin(scores)

    return best, pca_frame.product_name.iloc[best], pca_frame.index[best], pd.np.min(scores)

# %%
closest_product(1, output=False)
# Out:
# best match for: Chocolate Sandwich Cookies
# (26437, 'Veggie Cheese & Pretzel Snack Pac Prepacked', 30633, 1.316407)

# %%
multi_closest_product([1, 2])
# Out:
# best match for: Chocolate Sandwich Cookies
# best match for: All-Seasons Salt
# (16,)
# (2100, 'Peppermint Gum', 2458, 1.294741)

# %% [markdown]
# # Recommend some stuff!

# %%
l = []
for i in pca_frame.index.values[:10]:
    l.append(i)
    print(multi_closest_product(l))
    print()
# Out:
# best match for: Chocolate Sandwich Cookies
# (16,)
# (26437, 'Veggie Cheese & Pretzel Snack Pac Prepacked', 30633, 1.316407)
#
# best match for: Chocolate Sandwich Cookies
# best match for: All-Seasons Salt
# (16,)
# (2100, 'Peppermint Gum', 2458, 1.294741)
#
# best match for: Chocolate Sandwich Cookies
# best match for: All-Seasons Salt
# best match for: Robust Golden Unsweetened Oolong Tea
# (16,)
# (39674, 'Double Chocolate Muffins', 46065, 1.6965892)
#
# best match for: Chocolate Sandwich Cookies
# best match for: All-Seasons Salt
# best match for: Robust Golden Unsweetened Oolong Tea
# best match for: Smart Ones Classic Favorites Mini Rigatoni With Vodka Cream Sauce
# (16,)
# (25659, 'Caffeine Free Diet Coke', 29735, 1.8516276)
#
# best match for: Chocolate Sandwich Cookies
# best match for: All-Seasons Salt
# best match for: Robust Golden Unsweetened Oolong Tea
# best match for: Smart Ones Classic Favorites Mini Rigatoni With Vodka Cream Sauce
# best match for: Green Chile Anytime Sauce
# (16,)
# (31644, 'Organic Agave Nectar', 36672, 1.5027165)
#
# best match for: Chocolate Sandwich Cookies
# best match for: All-Seasons Salt
# best match for: Robust Golden Unsweetened Oolong Tea
# best match for: Smart Ones Classic Favorites Mini Rigatoni With Vodka Cream Sauce
# best match for: Green Chile Anytime Sauce
# best match for: Pure Coconut Water With Orange
# (16,)
# (24903, 'Melograno e Arancia Sparkling Pomegranate & Orange Beverage', 28866, 1.2849264)
#
# best match for: Chocolate Sandwich Cookies
# best match for: All-Seasons Salt
# best match for: Robust Golden Unsweetened Oolong Tea
# best match for: Smart Ones Classic Favorites Mini Rigatoni With Vodka Cream Sauce
# best match for: Green Chile Anytime Sauce
# best match for: Pure Coconut Water With Orange
# best match for: Cut Russet Potatoes Steam N' Mash
# (16,)
# (10394, 'Fire Roasted Jalapeño Pita Chips', 12092, 1.185301)
#
# best match for: Chocolate Sandwich Cookies
# best match for: All-Seasons Salt
# best match for: Robust Golden Unsweetened Oolong Tea
# best match for: Smart Ones Classic Favorites Mini Rigatoni With Vodka Cream Sauce
# best match for: Green Chile Anytime Sauce
# best match for: Pure Coconut Water With Orange
# best match for: Cut Russet Potatoes Steam N' Mash
# best match for: Light Strawberry Blueberry Yogurt
# (16,)
# (10394, 'Fire Roasted Jalapeño Pita Chips', 12092, 1.1202922)
#
# best match for: Chocolate Sandwich Cookies
# best match for: All-Seasons Salt
# best match for: Robust Golden Unsweetened Oolong Tea
# best match for: Smart Ones Classic Favorites Mini Rigatoni With Vodka Cream Sauce
# best match for: Green Chile Anytime Sauce
# best match for: Pure Coconut Water With Orange
# best match for: Cut Russet Potatoes Steam N' Mash
# best match for: Light Strawberry Blueberry Yogurt
# best match for: Sparkling Orange Juice & Prickly Pear Beverage
# (16,)
# (15296, 'Spicy Minis Guacamole', 17715, 1.7444391)
#
# best match for: Chocolate Sandwich Cookies
# best match for: All-Seasons Salt
# best match for: Robust Golden Unsweetened Oolong Tea
# best match for: Smart Ones Classic Favorites Mini Rigatoni With Vodka Cream Sauce
# best match for: Green Chile Anytime Sauce
# best match for: Pure Coconut Water With Orange
# best match for: Cut Russet Potatoes Steam N' Mash
# best match for: Light Strawberry Blueberry Yogurt
# best match for: Sparkling Orange Juice & Prickly Pear Beverage
# best match for: Peach Mango Juice
# (16,)
# (4501, 'Black Bean Chipotle Vegan', 5218, 1.7010388)

# %%
def generate_recs(i):
    try:
        basket = orders.iloc[i]
        actual_last = basket[-1]
        basket = basket[:-1]
    except KeyError:
        print('order_id {} may exist in orders.index, but contains no items. \n'.format(orders.index[i]))
        return None
    
    print('\n' + '+ ' * 30 + '\n')
    print(pca_frame.loc[basket].product_name)

    ind, name, product_id, score = multi_closest_product(basket)
    
    print()
    print('we chose:')
    print(name)

    print()
    print('actual final item:')
    print(pca_frame.loc[actual_last].product_name)
    
    print()
    print('distance between items:', distance(product_id, actual_last))
        
    print()

# %%
for _ in range(20):
    generate_recs(pd.np.random.randint(0, 10000))
# Out:
# + + + + + + + + + + + + + + + + + + + + + + + + + + + + + +
#
# Series([], Name: product_name, dtype: object)
# (16,)
#
# we chose:
# Chocolate Sandwich Cookies
#
# actual final item:
# Freshly Squeezed Orange Juice
#
# distance from: Chocolate Sandwich Cookies  to  Freshly Squeezed Orange Juice
# distance between items: 24.96351
#
#
# + + + + + + + + + + + + + + + + + + + + + + + + + + + + + +
#
# product_id
# 47877                                            Coke Zero
# 19173                 Orange Calcium & Vitamin D Pulp Free
# 19033    Vaporizing Decongestant Vicks VapoRub Cough Su...
# 28760                 Soup Secrets Chicken Noodle Soup Mix
# 24761              Slow Kettle Roasted Chicken Noodle Soup
# 34898      Low Moisture Part Skim Mozzarella String Cheese
# 23687                           Multi Grain Sandwich Thins
# 4986                              Light Butter with Canola
# 17545                                   Rotisserie Chicken
# 22619                      Cool Whipe Lite Whipped Topping
# Name: product_name, dtype: object
# best match for: Coke Zero
# best match for: Orange Calcium & Vitamin D Pulp Free
# best match for: Vaporizing Decongestant Vicks VapoRub Cough Suppressant Topical Analgesic Ointment
# best match for: Soup Secrets Chicken Noodle Soup Mix
# best match for: Slow Kettle Roasted Chicken Noodle Soup
# best match for: Low Moisture Part Skim Mozzarella String Cheese
# best match for: Multi Grain Sandwich Thins
# best match for: Light Butter with Canola
# best match for: Rotisserie Chicken
# best match for: Cool Whipe Lite Whipped Topping
# (16,)
#
# we chose:
# Breakfast Veggie Bacon Strips
#
# actual final item:
# Buffalo Style Boneless Chicken Wyngz
#
# distance from: Breakfast Veggie Bacon Strips  to  Buffalo Style Boneless Chicken Wyngz
# distance between items: 8.557163
#
#
# + + + + + + + + + + + + + + + + + + + + + + + + + + + + + +
#
# product_id
# 20776    Organic Quinoa
# Name: product_name, dtype: object
# best match for: Organic Quinoa
# (16,)
#
# we chose:
# Organic Triple Berry Blend
#
# actual final item:
# Organic Chia Seeds
#
# distance from: Organic Triple Berry Blend  to  Organic Chia Seeds
# distance between items: 4.2656674
#
#
# + + + + + + + + + + + + + + + + + + + + + + + + + + + + + +
#
# Series([], Name: product_name, dtype: object)
# (16,)
#
# we chose:
# Chocolate Sandwich Cookies
#
# actual final item:
# Organic Simply Naked Pita Chips
#
# distance from: Chocolate Sandwich Cookies  to  Organic Simply Naked Pita Chips
# distance between items: 3.87641
#
#
# + + + + + + + + + + + + + + + + + + + + + + + + + + + + + +
#
# product_id
# 3957                                100% Raw Coconut Water
# 20084      Pineapple Apple Mint Organic Cold Pressed Juicd
# 25466                                                Water
# 39558                                          Gold Potato
# 40878                                  Macaroni And Cheese
# 49235                                  Organic Half & Half
# 41950                               Organic Tomato Cluster
# 8630                             Baby Calendula Body Cream
# 2722     Raw Probiotics Women probiotic 85 Billion 32 S...
# 19660                                         Spring Water
# Name: product_name, dtype: object
# best match for: 100% Raw Coconut Water
# best match for: Pineapple Apple Mint Organic Cold Pressed Juicd
# best match for: Water
# best match for: Gold Potato
# best match for: Macaroni And Cheese
# best match for: Organic Half & Half
# best match for: Organic Tomato Cluster
# best match for: Baby Calendula Body Cream
# best match for: Raw Probiotics Women probiotic 85 Billion 32 Strains capsules
# best match for: Spring Water
# (16,)
# /home/sam/.envs/instacart/lib/python3.5/site-packages/numpy/core/fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/sam/.envs/instacart/lib/python3.5/site-packages/numpy/core/_methods.py:73: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# /home/sam/.envs/instacart/lib/python3.5/site-packages/numpy/core/_methods.py:29: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims)
# we chose:
# Original Enriched Rice Drink
#
# actual final item:
# Pure Irish Butter
#
# distance from: Original Enriched Rice Drink  to  Pure Irish Butter
# distance between items: 10.195543
#
#
# + + + + + + + + + + + + + + + + + + + + + + + + + + + + + +
#
# product_id
# 28842                   Bunched Cilantro
# 28348    Organic Kidney Beans Low Sodium
# 28954         Classic Rotisserie Chicken
# Name: product_name, dtype: object
# best match for: Bunched Cilantro
# best match for: Organic Kidney Beans Low Sodium
# best match for: Classic Rotisserie Chicken
# (16,)
#
# we chose:
# Pistachio Pistachio Ice Cream
#
# actual final item:
# White Onion
#
# distance from: Pistachio Pistachio Ice Cream  to  White Onion
# distance between items: 16.630404
#
#
# + + + + + + + + + + + + + + + + + + + + + + + + + + + + + +
#
# product_id
# 30391                      Organic Cucumber
# 24964                        Organic Garlic
# 15200                   Organic Green Beans
# 21903                  Organic Baby Spinach
# 1244             Organic Orange Bell Pepper
# 45007                      Organic Zucchini
# 22935                  Organic Yellow Onion
# 47209                  Organic Hass Avocado
# 33342      Organic Red Grape Tomato Package
# 28597    Organic Stoneground Wheat Crackers
# 31717                      Organic Cilantro
# 26209                                 Limes
# 5876                          Organic Lemon
# 37029                   Cream Cheese Spread
# Name: product_name, dtype: object
# best match for: Organic Cucumber
# best match for: Organic Garlic
# best match for: Organic Green Beans
# best match for: Organic Baby Spinach
# best match for: Organic Orange Bell Pepper
# best match for: Organic Zucchini
# best match for: Organic Yellow Onion
# best match for: Organic Hass Avocado
# best match for: Organic Red Grape Tomato Package
# best match for: Organic Stoneground Wheat Crackers
# best match for: Organic Cilantro
# best match for: Limes
# best match for: Organic Lemon
# best match for: Cream Cheese Spread
# (16,)
#
# we chose:
# Organic Whipped Naturally Buttery Spread
#
# actual final item:
# Organic Garnet Sweet Potato (Yam)
#
# distance from: Organic Whipped Naturally Buttery Spread  to  Organic Garnet Sweet Potato (Yam)
# distance between items: 5.272803
#
#
# + + + + + + + + + + + + + + + + + + + + + + + + + + + + + +
#
# product_id
# 9803                       Organic Vanilla Oat Beverage
# 19322            Original Flax Milk Dairy Free Protein+
# 33232                           Unsweetened Cashew Milk
# 11760                      7 Whole Grain Nuggets Cereal
# 39967             Cacao Nib Crunch Stone Ground Organic
# 18027    Ezekiel 4:9 Bread Organic Sprouted Whole Grain
# 8988                              Organic Garlic Powder
# Name: product_name, dtype: object
# best match for: Organic Vanilla Oat Beverage
# best match for: Original Flax Milk Dairy Free Protein+
# best match for: Unsweetened Cashew Milk
# best match for: 7 Whole Grain Nuggets Cereal
# best match for: Cacao Nib Crunch Stone Ground Organic
# best match for: Ezekiel 4:9 Bread Organic Sprouted Whole Grain
# best match for: Organic Garlic Powder
# (16,)
#
# we chose:
# Ginger Ale Jamaican Style
#
# actual final item:
# Organic Romaine Lettuce
#
# distance from: Ginger Ale Jamaican Style  to  Organic Romaine Lettuce
# distance between items: 18.61745
#
#
# + + + + + + + + + + + + + + + + + + + + + + + + + + + + + +
#
# product_id
# 10017                     Tilapia Filet
# 40706            Organic Grape Tomatoes
# 14267       Organic Refried Black Beans
# 24964                    Organic Garlic
# 781       Organic Shredded Mild Cheddar
# 22808    Honey Lemon Throat Comfort Tea
# 13176            Bag of Organic Bananas
# Name: product_name, dtype: object
# best match for: Tilapia Filet
# best match for: Organic Grape Tomatoes
# best match for: Organic Refried Black Beans
# best match for: Organic Garlic
# best match for: Organic Shredded Mild Cheddar
# best match for: Honey Lemon Throat Comfort Tea
# best match for: Bag of Organic Bananas
# (16,)
#
# we chose:
# Tahitian Vanilla Bean Gelato
#
# actual final item:
# Ranch Dressing
#
# distance from: Tahitian Vanilla Bean Gelato  to  Ranch Dressing
# distance between items: 4.860865
#
#
# + + + + + + + + + + + + + + + + + + + + + + + + + + + + + +
#
# product_id
# 20323                                    Strained Tomatoes
# 14252                                  Coke Zero Diet Soda
# 28083                            Healthy Multi Grain Bread
# 36736                                         Iodized Salt
# 44904                                          Garlic Salt
# 22684                                             Muenster
# 47479                              Squeeze Real Mayonnaise
# 31506                               Extra Virgin Olive Oil
# 12679                            Peppercorn Medley Grinder
# 18534                             Grade A Extra Large Eggs
# 8460                                Hearty Thick Cut Bacon
# 14280                                              Wieners
# 34968                      Enriched Poppyseed Hot Dog Buns
# 44234                               Squeeze Tomato Ketchup
# 32784           Natural Shredded Mexican Style Four Cheese
# 28842                                     Bunched Cilantro
# 47626                                          Large Lemon
# 20378                                        Chicken Broth
# 17341                          Presliced Everything Bagels
# 25084    Philadelphia Whipped Cream Cheese Spread with ...
# 612                       Rice, Extra Long Grain, Enriched
# 6101                                       Farfalle No. 93
# 14502                               Tri-Color Rotini Pasta
# Name: product_name, dtype: object
# best match for: Strained Tomatoes
# best match for: Coke Zero Diet Soda
# best match for: Healthy Multi Grain Bread
# best match for: Iodized Salt
# best match for: Garlic Salt
# best match for: Muenster
# best match for: Squeeze Real Mayonnaise
# best match for: Extra Virgin Olive Oil
# best match for: Peppercorn Medley Grinder
# best match for: Grade A Extra Large Eggs
# best match for: Hearty Thick Cut Bacon
# best match for: Wieners
# best match for: Enriched Poppyseed Hot Dog Buns
# best match for: Squeeze Tomato Ketchup
# best match for: Natural Shredded Mexican Style Four Cheese
# best match for: Bunched Cilantro
# best match for: Large Lemon
# best match for: Chicken Broth
# best match for: Presliced Everything Bagels
# best match for: Philadelphia Whipped Cream Cheese Spread with Chives
# best match for: Rice, Extra Long Grain, Enriched
# best match for: Farfalle No. 93
# best match for: Tri-Color Rotini Pasta
# (16,)
#
# we chose:
# 100% Pineapple Juice
#
# actual final item:
# Alfredo Pasta Sauce
#
# distance from: 100% Pineapple Juice  to  Alfredo Pasta Sauce
# distance between items: 11.890612
#
#
# + + + + + + + + + + + + + + + + + + + + + + + + + + + + + +
#
# product_id
# 39877          Organic Granny Smith Apple
# 45535    Organic Low Sodium Chicken Broth
# 41463                    Cannellini Beans
# 17429                     Jalapeno Hummus
# 48845            Roasted Brussels Sprouts
# 28849           No Salt Added Black Beans
# Name: product_name, dtype: object
# best match for: Organic Granny Smith Apple
# best match for: Organic Low Sodium Chicken Broth
# best match for: Cannellini Beans
# best match for: Jalapeno Hummus
# best match for: Roasted Brussels Sprouts
# best match for: No Salt Added Black Beans
# (16,)
#
# we chose:
# Cage Free  100% Liquid Egg Whites
#
# actual final item:
# Jalapeno Nacho Slices, Mild
#
# distance from: Cage Free  100% Liquid Egg Whites  to  Jalapeno Nacho Slices, Mild
# distance between items: 14.682855
#
#
# + + + + + + + + + + + + + + + + + + + + + + + + + + + + + +
#
# product_id
# 28934      Frozen Broccoli Florets
# 28849    No Salt Added Black Beans
# 40545                 Berry Medley
# 21903         Organic Baby Spinach
# 15290           Orange Bell Pepper
# 21872        Organic Italian Salad
# 10305                   Black Plum
# Name: product_name, dtype: object
# best match for: Frozen Broccoli Florets
# best match for: No Salt Added Black Beans
# best match for: Berry Medley
# best match for: Organic Baby Spinach
# best match for: Orange Bell Pepper
# best match for: Organic Italian Salad
# best match for: Black Plum
# (16,)
#
# we chose:
# Salted Butter
#
# actual final item:
# Organic Yams
#
# distance from: Salted Butter  to  Organic Yams
# distance between items: 3.043679
#
#
# + + + + + + + + + + + + + + + + + + + + + + + + + + + + + +
#
# product_id
# 49235    Organic Half & Half
# Name: product_name, dtype: object
# best match for: Organic Half & Half
# (16,)
#
# we chose:
# Organic Blackberries
#
# actual final item:
# Organic Extra Virgin Olive Oil
#
# distance from: Organic Blackberries  to  Organic Extra Virgin Olive Oil
# distance between items: 8.274337
#
#
# + + + + + + + + + + + + + + + + + + + + + + + + + + + + + +
#
# product_id
# 30639                                 Organic Orange Juice
# 19660                                         Spring Water
# 8555                           Sweet Potato Tortilla Chips
# 8670                                        Diced Tomatoes
# 21903                                 Organic Baby Spinach
# 26346                                    Organic Skim Milk
# 13292    Juice Beverage, Cold Pressed, Kale Apple Ginge...
# 39275                                  Organic Blueberries
# 29270    Beet Apple Carrot Lemon Ginger Organic Cold Pr...
# 11132                Organic Promise Berry Fruitful Cereal
# 7503                                         Whole Almonds
# 22935                                 Organic Yellow Onion
# 21724                                Stir-fry Rice Noodles
# 42440       Szechuan Hot & Spicy Marinade & Stir Fry Sauce
# 24964                                       Organic Garlic
# 31717                                     Organic Cilantro
# Name: product_name, dtype: object
# best match for: Organic Orange Juice
# best match for: Spring Water
# best match for: Sweet Potato Tortilla Chips
# best match for: Diced Tomatoes
# best match for: Organic Baby Spinach
# best match for: Organic Skim Milk
# best match for: Juice Beverage, Cold Pressed, Kale Apple Ginger Romaine Spinach Cucumber Celery Parsley Lemon
# best match for: Organic Blueberries
# best match for: Beet Apple Carrot Lemon Ginger Organic Cold Pressed Juice Beverage
# best match for: Organic Promise Berry Fruitful Cereal
# best match for: Whole Almonds
# best match for: Organic Yellow Onion
# best match for: Stir-fry Rice Noodles
# best match for: Szechuan Hot & Spicy Marinade & Stir Fry Sauce
# best match for: Organic Garlic
# best match for: Organic Cilantro
# (16,)
#
# we chose:
# Tahitian Vanilla Bean Gelato
#
# actual final item:
# Sustainably Soft Bath Tissue
#
# distance from: Tahitian Vanilla Bean Gelato  to  Sustainably Soft Bath Tissue
# distance between items: 5.0452576
#
#
# + + + + + + + + + + + + + + + + + + + + + + + + + + + + + +
#
# Series([], Name: product_name, dtype: object)
# (16,)
# we chose:
# Chocolate Sandwich Cookies
#
# actual final item:
# Pure Irish Butter
#
# distance from: Chocolate Sandwich Cookies  to  Pure Irish Butter
# distance between items: 29.250433
#
#
# + + + + + + + + + + + + + + + + + + + + + + + + + + + + + +
#
# product_id
# 21137            Organic Strawberries
# 46979                       Asparagus
# 41290                        Lemonade
# 44292    Premium Unsweetened Iced Tea
# 45                  European Cucumber
# 26209                           Limes
# 44275          Mini Blueberry Muffins
# Name: product_name, dtype: object
# best match for: Organic Strawberries
# best match for: Asparagus
# best match for: Lemonade
# best match for: Premium Unsweetened Iced Tea
# best match for: European Cucumber
# best match for: Limes
# best match for: Mini Blueberry Muffins
# (16,)
#
# we chose:
# Boomchickapop Sea Salt Popcorn
#
# actual final item:
# Original BBQ Sauce
#
# distance from: Boomchickapop Sea Salt Popcorn  to  Original BBQ Sauce
# distance between items: 9.459295
#
#
# + + + + + + + + + + + + + + + + + + + + + + + + + + + + + +
#
# product_id
# 48205                              Spinach
# 24852                               Banana
# 13519                 Original Cracklebred
# 28851    Cage Free  100% Liquid Egg Whites
# 47209                 Organic Hass Avocado
# 35951      Organic Unsweetened Almond Milk
# Name: product_name, dtype: object
# best match for: Spinach
# best match for: Banana
# best match for: Original Cracklebred
# best match for: Cage Free  100% Liquid Egg Whites
# best match for: Organic Hass Avocado
# best match for: Organic Unsweetened Almond Milk
# (16,)
#
# we chose:
# Apple Pie Fruit & Nut Food Bar
#
# actual final item:
# Fat Free Plain Yogurt
#
# distance from: Apple Pie Fruit & Nut Food Bar  to  Fat Free Plain Yogurt
# distance between items: 11.584962
#
#
# + + + + + + + + + + + + + + + + + + + + + + + + + + + + + +
#
# product_id
# 17807                        Gluten Free Blueberry Waffles
# 17830                    Premium Organic Strawberry Spread
# 20327           Organic All Natural Blueberry Mini Waffles
# 18389                            Blood Orange Italian Soda
# 31238                             Blue Corn Tortilla Chips
# 36481           Organic Gluten Free Maple Buckwheat Flakes
# 24561                          Organic Cheese Frozen Pizza
# 34688    Good Belly Probiotics Juice Drink Blueberry Ac...
# 48747             Oh My Yog! Gingered Pear Trilayer Yogurt
# 36496            Oh My Yog! Trilayer Yogurt Apple Cinnamon
# 13740         Organic Summer Strawberry Bunny Fruit Snacks
# 1774                                Butter Pecan Ice Cream
# 2326                             Organic Blueberry Waffles
# 45208                     Organic Cinnamon Graham Crackers
# 17861    Cinnamon Bunny Grahams Whole Grain Graham Snac...
# Name: product_name, dtype: object
# best match for: Gluten Free Blueberry Waffles
# best match for: Premium Organic Strawberry Spread
# best match for: Organic All Natural Blueberry Mini Waffles
# best match for: Blood Orange Italian Soda
# best match for: Blue Corn Tortilla Chips
# best match for: Organic Gluten Free Maple Buckwheat Flakes
# best match for: Organic Cheese Frozen Pizza
# best match for: Good Belly Probiotics Juice Drink Blueberry Acai Flavor
# best match for: Oh My Yog! Gingered Pear Trilayer Yogurt
# best match for: Oh My Yog! Trilayer Yogurt Apple Cinnamon
# best match for: Organic Summer Strawberry Bunny Fruit Snacks
# best match for: Butter Pecan Ice Cream
# best match for: Organic Blueberry Waffles
# best match for: Organic Cinnamon Graham Crackers
# best match for: Cinnamon Bunny Grahams Whole Grain Graham Snacks Bunny Grahams
# (16,)
#
# we chose:
# Low Fat No Chicken Noodle Soup
#
# actual final item:
# Caramel Cookie Crunch Gelato
#
# distance from: Low Fat No Chicken Noodle Soup  to  Caramel Cookie Crunch Gelato
# distance between items: 8.689238
#
#
# + + + + + + + + + + + + + + + + + + + + + + + + + + + + + +
#
# product_id
# 6475               Limonata Sparkling Lemon Beverage
# 44375                        Canned Aranciata Orange
# 18531                   Organic Heavy Whipping Cream
# 43428                                 Pure Green Tea
# 49683                                 Cucumber Kirby
# 41613    Gochujang Fermented Chile Paste Concentrate
# 27958                             Chicken Drumsticks
# 31553                              Fresh Ginger Root
# 8424                                  Broccoli Crown
# 32652                          Organic Broccoli Slaw
# 16797                                   Strawberries
# 34128                                       Tzatziki
# 5025                                    Green Onions
# 47766                                Organic Avocado
# 9766                Avocado Oil Himalayan Salt Chips
# Name: product_name, dtype: object
# best match for: Limonata Sparkling Lemon Beverage
# best match for: Canned Aranciata Orange
# best match for: Organic Heavy Whipping Cream
# best match for: Pure Green Tea
# best match for: Cucumber Kirby
# best match for: Gochujang Fermented Chile Paste Concentrate
# best match for: Chicken Drumsticks
# best match for: Fresh Ginger Root
# best match for: Broccoli Crown
# best match for: Organic Broccoli Slaw
# best match for: Strawberries
# best match for: Tzatziki
# best match for: Green Onions
# best match for: Organic Avocado
# best match for: Avocado Oil Himalayan Salt Chips
# (16,)
#
# we chose:
# Gluten Free White Sandwich Bread
#
# actual final item:
# Canola Oil
#
# distance from: Gluten Free White Sandwich Bread  to  Canola Oil
# distance between items: 6.4263206
#
#
# + + + + + + + + + + + + + + + + + + + + + + + + + + + + + +
#
# Series([], Name: product_name, dtype: object)
# (16,)
#
# we chose:
# Chocolate Sandwich Cookies
#
# actual final item:
# Seedless Red Grapes
#
# distance from: Chocolate Sandwich Cookies  to  Seedless Red Grapes
# distance between items: 30.021465

# %% [markdown]
# # Recommender works... ok!
#
# Recommendations are generally reasonable and fall in the space of products that these consumers may purchse.
#
# ### Things to improve:
#
# This system only uses our PCA distance metric. It could definitely be improved by using other available data:
# 0. The way distances are dealt with here is dumb! Average vs. cluster
# 1. Department/Aisle info
# 2. Product add-to-order sequence data
# 3. Time of day/week information
# 4. (customer purchase history if this was for real deployment)
# 5. Text from product description
# 6. Most of product graph was thrown out (for RAM / time / complexity)
# 7. Internal parameters (# dimensions, 'oddity') have not been tuned
#
# # Ultimately, this system is only measuring fake distances and finding the closest items. It could probably be more nuanced
